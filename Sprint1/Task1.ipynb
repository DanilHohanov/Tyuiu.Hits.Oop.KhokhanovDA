// %% [markdown]
// <h1 style="color:DodgerBlue">Структура и объявление класса, через: свойства, геттеры и сеттеры</h1>

// %% [markdown]
// ### Структура и Объявление Класса в C#
//
// В C#, класс объявляется с использованием ключевого слова `class`, за которым следует имя класса. Класс может содержать поля (данные), свойства (способ доступа к данным), методы (функциональность) и события.
//
// #### Свойства
//
// Свойства в C# используются для инкапсуляции данных. Они предоставляют гибкий механизм для чтения, записи или вычисления значений приватных полей. Свойства могут иметь два акцессора: `get` (геттер) для чтения значения и `set` (сеттер) для его изменения.
//
// #### Геттеры и Сеттеры
//
// Геттеры и сеттеры являются частью свойств класса в C#. Геттер (`get`) используется для возврата значения свойства, а сеттер (`set`) — для установки нового значения. Сеттер может включать логику валидации или другие операции перед изменением значения поля.
//
// ### Пример Классов Vehicle и Car
//
// Давайте рассмотрим примеры классов `Vehicle` и `Car`, чтобы проиллюстрировать использование свойств, геттеров и сеттеров, а также разницу между статическими и обычными атрибутами и методами.
//
// #### Класс Vehicle
//
// ```csharp
// public class Vehicle
// {
//     private string _color;
//     private int _speed;
//
//     // Свойство Color с геттером и сеттером
//     public string Color
//     {
//         get { return _color; }
//         set { _color = value; }
//     }
//
//     // Свойство Speed с геттером и сеттером
//     public int Speed
//     {
//         get { return _speed; }
//         set
//         {
//             if (value >= 0)
//                 _speed = value;
//             else
//                 throw new ArgumentOutOfRangeException("Скорость не может быть отрицательной!");
//         }
//     }
//
//     // Статический атрибут
//     public static int TotalVehicles { get; private set; } = 0;
//
//     // Конструктор
//     public Vehicle()
//     {
//         TotalVehicles++;
//     }
//
//     // Обычный метод
//     public void Accelerate(int delta)
//     {
//         Speed += delta;
//     }
//
//     // Статический метод
//     public static void DisplayTotalVehicles()
//     {
//         Console.WriteLine($"Общее количество транспортных средств: {TotalVehicles}");
//     }
// }
// ```
//
// #### Класс Car
//
// ```csharp
// public class Car : Vehicle
// {
//     private int _fuelLevel;
//
//     // Свойство FuelLevel с геттером и сеттером
//     public int FuelLevel
//     {
//         get { return _fuelLevel; }
//         set { _fuelLevel = value; }
//     }
//
//     // Конструктор
//     public Car() : base()
//     {
//         FuelLevel = 100; // Задаем начальный уровень топлива
//     }
//
//     // Обычный метод
//     public void Refuel(int amount)
//     {
//         FuelLevel += amount;
//     }
// }
// ```
//
// ### Разница между Статическими и Обычными Атрибутами и Методами Класса
//
// - **Статические атрибуты и методы** принадлежат самому классу, а не его экземплярам. Они могут быть вызваны без создания объекта класса. В примере выше `TotalVehicles` является статическим атрибутом, а `DisplayTotalVehicles()` — статическим методом класса `Vehicle`.
// - **Обычные атрибуты и методы** принадлежат экземплярам класса и могут иметь разные значения для разных объектов. В примере выше `_color`, `_speed` и `_fuelLevel` являются обычными атрибутами, а методы `Accelerate()` и `Refuel()` — обычными методами.
//
// ### Заключение
//
// В этом таске мы рассмотрели структуру и объявление класса в C#, включая свойства, геттеры и сеттеры, а также разницу между статическими и обычными атрибутами и методами класса на примерах классов `Vehicle` и `Car`. Эти концепции являются основой для создания объектно-ориентированных программ на C#.

// %% [markdown]
// <h4 style="color:DodgerBlue">Для проверки напишите пример кода на основе классов Car и Vehicle ниже в блоке:</h4>
//
// ----

// %%
public class Vehicle
{
    private string _color;
    private int _speed;

    // Свойство Color с геттером и сеттером
    public string Color
    {
        get { return _color; }
        set { _color = value; }
    }

    // Свойство Speed с геттером и сеттером
    public int Speed
    {
        get { return _speed; }
        set
        {
            if (value >= 0)
                _speed = value;
            else
                throw new ArgumentOutOfRangeException("Скорость не может быть отрицательной!");
        }
    }

    // Статический атрибут
    public static int TotalVehicles { get; private set; } = 0;

    // Конструктор
    public Vehicle()
    {
        TotalVehicles++;
    }

    // Обычный метод
    public void Accelerate(int delta)
    {
        Speed += delta;
    }

    // Статический метод
    public static void DisplayTotalVehicles()
    {
        Console.WriteLine($"Общее количество транспортных средств: {TotalVehicles}");
    }
}

public class Car : Vehicle
{
    private int _fuelLevel;

    // Свойство FuelLevel с геттером и сеттером
    public int FuelLevel
    {
        get { return _fuelLevel; }
        set { _fuelLevel = value; }
    }

    // Конструктор
    public Car() : base()
    {
        FuelLevel = 100; // Задаем начальный уровень топлива
    }

    // Обычный метод
    public void Refuel(int amount)
    {
        FuelLevel += amount;
    }
}

// %% [markdown]
// <h4 style="color:Red">Задание:</h4>
//
// ----
//
// Ниже в блоке по примеру создайте базовый класс Animal и производные классы (2-3 например Dog, Cat и так далее) реализуйте структуру и объявление класса, включая свойства, геттеры и сеттеры, а также статические и обычными атрибуты и метода класса

// %%
using System;

// === БАЗОВЫЙ КЛАСС ANIMAL ===
public class Animal
{
    // Статический атрибут
    public static int TotalAnimals { get; private set; }

    // Обычные атрибуты (поля)
    private string _name;
    private int _age;
    private double _weight;

    // Свойства с геттерами и сеттерами
    public string Name
    {
        get { return _name; }
        set 
        { 
            if (!string.IsNullOrEmpty(value))
                _name = value;
        }
    }

    public int Age
    {
        get { return _age; }
        set 
        { 
            if (value >= 0 && value <= 50)
                _age = value;
        }
    }

    public double Weight
    {
        get { return _weight; }
        set 
        { 
            if (value > 0)
                _weight = value;
        }
    }

    // Конструктор
    public Animal(string name, int age, double weight)
    {
        Name = name;
        Age = age;
        Weight = weight;
        TotalAnimals++;
    }

    // Обычные методы класса
    public virtual void MakeSound()
    {
        Console.WriteLine($"{_name} издает звук...");
    }

    public virtual void Eat()
    {
        Console.WriteLine($"{_name} ест...");
    }

    public void Sleep()
    {
        Console.WriteLine($"{_name} спит...");
    }

    // Статический метод
    public static void DisplayTotalAnimals()
    {
        Console.WriteLine($"Всего животных создано: {TotalAnimals}");
    }

    public override string ToString()
    {
        return $"Имя: {_name}, Возраст: {_age}, Вес: {_weight} кг";
    }
}

// === ПРОИЗВОДНЫЙ КЛАСС DOG ===
public class Dog : Animal
{
    private string _breed;
    private bool _isTrained;

    public string Breed
    {
        get { return _breed; }
        set { _breed = value; }
    }

    public bool IsTrained
    {
        get { return _isTrained; }
        set { _isTrained = value; }
    }

    public Dog(string name, int age, double weight, string breed) 
        : base(name, age, weight)
    {
        Breed = breed;
        IsTrained = false;
    }

    public override void MakeSound()
    {
        Console.WriteLine($"{Name} лает: Гав-гав!");
    }

    public override void Eat()
    {
        Console.WriteLine($"{Name} ест собачий корм...");
    }

    public void Fetch()
    {
        if (_isTrained)
            Console.WriteLine($"{Name} приносит мячик!");
        else
            Console.WriteLine($"{Name} не обучен приносить предметы.");
    }

    public void Train()
    {
        _isTrained = true;
        Console.WriteLine($"{Name} теперь обучен!");
    }
}

// === ПРОИЗВОДНЫЙ КЛАСС CAT ===
public class Cat : Animal
{
    private string _color;
    private bool _isIndoor;

    public string Color
    {
        get { return _color; }
        set { _color = value; }
    }

    public bool IsIndoor
    {
        get { return _isIndoor; }
        set { _isIndoor = value; }
    }

    public Cat(string name, int age, double weight, string color, bool isIndoor) 
        : base(name, age, weight)
    {
        Color = color;
        IsIndoor = isIndoor;
    }

    public override void MakeSound()
    {
        Console.WriteLine($"{Name} мяукает: Мяяяу!");
    }

    public override void Eat()
    {
        Console.WriteLine($"{Name} ест кошачий корм...");
    }

    public void Purr()
    {
        Console.WriteLine($"{Name} мурлычет...");
    }

    public void Scratch()
    {
        Console.WriteLine($"{Name} точит когти...");
    }

    public void CheckLifestyle()
    {
        Console.WriteLine($"{Name} - {(_isIndoor ? "домашняя" : "уличная")} кошка");
    }
}

// === ПРОИЗВОДНЫЙ КЛАСС BIRD ===
public class Bird : Animal
{
    private double _wingSpan;
    private bool _canFly;

    public double WingSpan
    {
        get { return _wingSpan; }
        set { _wingSpan = value; }
    }

    public bool CanFly
    {
        get { return _canFly; }
        set { _canFly = value; }
    }

    public Bird(string name, int age, double weight, double wingSpan) 
        : base(name, age, weight)
    {
        WingSpan = wingSpan;
        CanFly = true;
    }

    public override void MakeSound()
    {
        Console.WriteLine($"{Name} поет: Чик-чирик!");
    }

    public override void Eat()
    {
        Console.WriteLine($"{Name} клюет зерна...");
    }

    public void Fly()
    {
        Console.WriteLine($"{Name} {(CanFly ? "летит на высоте..." : "не может летать!")}");
    }

    public void BuildNest()
    {
        Console.WriteLine($"{Name} строит гнездо...");
    }
}

// === ДЕМОСТРАЦИЯ РАБОТЫ КЛАССОВ ===
Console.WriteLine("╔════════════════════════════════════╗");
Console.WriteLine("║  ДЕМОСТРАЦИЯ КЛАССОВ ANIMAL, DOG, CAT, BIRD  ║");
Console.WriteLine("╚════════════════════════════════════╝\n");

// 1. Создание объектов
Console.WriteLine("📋 1. СОЗДАНИЕ ОБЪЕКТОВ:");
Console.WriteLine("------------------------");
Dog dog = new Dog("Шарик", 3, 15.5, "Немецкая овчарка");
Cat cat = new Cat("Мурзик", 2, 4.2, "Рыжий", true);
Bird bird = new Bird("Кеша", 1, 0.5, 30.0);
Console.WriteLine("✓ Созданы: собака, кошка, птица\n");

// 2. Демонстрация свойств (геттеры/сеттеры)
Console.WriteLine("🔧 2. РАБОТА СО СВОЙСТВАМИ:");
Console.WriteLine("---------------------------");
Console.WriteLine($"Собака: {dog.Name}, Порода: {dog.Breed}");
Console.WriteLine($"Кошка: {cat.Name}, Цвет: {cat.Color}, Домашняя: {cat.IsIndoor}");
Console.WriteLine($"Птица: {bird.Name}, Размах крыльев: {bird.WingSpan} см");

// Изменение через сеттер
dog.Age = 4;
Console.WriteLine($"\n✓ Возраст собаки изменен на: {dog.Age}");

// Валидация в сеттере
cat.Age = 100; // Не изменится, т.к. > 50
Console.WriteLine($"✓ Попытка установить возраст 100: реальный возраст = {cat.Age}\n");

// 3. Демонстрация методов базового класса
Console.WriteLine("🎯 3. МЕТОДЫ БАЗОВОГО КЛАССА:");
Console.WriteLine("------------------------------");
Animal genericAnimal = new Animal("Зверь", 5, 10.0);
genericAnimal.MakeSound();
genericAnimal.Eat();
genericAnimal.Sleep();
Console.WriteLine();

// 4. Демонстрация переопределённых методов (полиморфизм)
Console.WriteLine("🔄 4. ПОЛИМОРФИЗМ - ПЕРЕОПРЕДЕЛЕНИЕ МЕТОДОВ:");
Console.WriteLine("-------------------------------------------");
dog.MakeSound();  // Вызывает Dog.MakeSound()
dog.Eat();        // Вызывает Dog.Eat()
Console.WriteLine();

cat.MakeSound();  // Вызывает Cat.MakeSound()
cat.Eat();        // Вызывает Cat.Eat()
Console.WriteLine();

bird.MakeSound(); // Вызывает Bird.MakeSound()
bird.Eat();       // Вызывает Bird.Eat()
Console.WriteLine();

// 5. Специфичные методы производных классов
Console.WriteLine("⭐ 5. СПЕЦИФИЧНЫЕ МЕТОДЫ ПРОИЗВОДНЫХ КЛАССОВ:");
Console.WriteLine("--------------------------------------------");
Console.WriteLine("→ Собака:");
dog.Train();
dog.Fetch();
Console.WriteLine();

Console.WriteLine("→ Кошка:");
cat.Purr();
cat.Scratch();
cat.CheckLifestyle();
Console.WriteLine();

Console.WriteLine("→ Птица:");
bird.Fly();
bird.BuildNest();
Console.WriteLine();

// 6. Демонстрация статического члена
Console.WriteLine("📊 6. СТАТИЧЕСКИЙ ЧЛЕН КЛАССА:");
Console.WriteLine("-------------------------------");
Animal.DisplayTotalAnimals();
Console.WriteLine();

// 7. Демонстрация полиморфизма через массив базового типа
Console.WriteLine("🎭 7. ПОЛИМОРФИЗМ ЧЕРЕЗ МАССИВ БАЗОВОГО ТИПА:");
Console.WriteLine("---------------------------------------------");
Animal[] animals = { dog, cat, bird };
Console.WriteLine("Вызов MakeSound() для всех животных:");
foreach (var animal in animals)
{
    animal.MakeSound(); // Автоматически вызывается правильный метод!
}
Console.WriteLine();

// 8. Демонстрация ToString()
Console.WriteLine("📝 8. ПЕРЕОПРЕДЕЛЕНИЕ ToString():");
Console.WriteLine("----------------------------------");
Console.WriteLine(dog.ToString());
Console.WriteLine(cat.ToString());
Console.WriteLine(bird.ToString());
Console.WriteLine();

// 9. Демонстрация валидации в свойствах
Console.WriteLine("🛡️ 9. ВАЛИДАЦИЯ В СЕТТЕРАХ:");
Console.WriteLine("---------------------------");
Console.WriteLine("Попытка установить отрицательный вес:");
dog.Weight = -10;
Console.WriteLine($"✓ Вес собаки остался: {dog.Weight} кг (отрицательное значение отклонено)");

Console.WriteLine("\nПопытка установить пустое имя:");
cat.Name = "";
Console.WriteLine($"✓ Имя кошки осталось: '{cat.Name}' (пустое значение отклонено)\n");

// 10. Финальный итог
Console.WriteLine("╔════════════════════════════════════╗");
Console.WriteLine("║         ИТОГИ ДЕМОСТРАЦИИ          ║");
Console.WriteLine("╚════════════════════════════════════╝");
Console.WriteLine($"✓ Создано животных всего: {Animal.TotalAnimals}");
Console.WriteLine($"✓ Продемонстрировано:");
Console.WriteLine("  • Структура класса и наследование");
Console.WriteLine("  • Свойства с геттерами/сеттерами");
Console.WriteLine("  • Статические и обычные члены");
Console.WriteLine("  • Переопределение методов (полиморфизм)");
Console.WriteLine("  • Валидация данных в свойствах");
Console.WriteLine("  • Специфичные методы производных классов");
// Out:
// ╔════════════════════════════════════╗
// ║  ДЕМОСТРАЦИЯ КЛАССОВ ANIMAL, DOG, CAT, BIRD  ║
// ╚════════════════════════════════════╝
//
// 📋 1. СОЗДАНИЕ ОБЪЕКТОВ:
// ------------------------
// ✓ Созданы: собака, кошка, птица
//
// 🔧 2. РАБОТА СО СВОЙСТВАМИ:
// ---------------------------
// Собака: Шарик, Порода: Немецкая овчарка
// Кошка: Мурзик, Цвет: Рыжий, Домашняя: True
// Птица: Кеша, Размах крыльев: 30 см
//
// ✓ Возраст собаки изменен на: 4
// ✓ Попытка установить возраст 100: реальный возраст = 2
//
// 🎯 3. МЕТОДЫ БАЗОВОГО КЛАССА:
// ------------------------------
// Зверь издает звук...
// Зверь ест...
// Зверь спит...
//
// 🔄 4. ПОЛИМОРФИЗМ - ПЕРЕОПРЕДЕЛЕНИЕ МЕТОДОВ:
// -------------------------------------------
// Шарик лает: Гав-гав!
// Шарик ест собачий корм...
//
// Мурзик мяукает: Мяяяу!
// Мурзик ест кошачий корм...
//
// Кеша поет: Чик-чирик!
// Кеша клюет зерна...
//
// ⭐ 5. СПЕЦИФИЧНЫЕ МЕТОДЫ ПРОИЗВОДНЫХ КЛАССОВ:
// --------------------------------------------
// → Собака:
// Шарик теперь обучен!
// Шарик приносит мячик!
//
// → Кошка:
// Мурзик мурлычет...
// Мурзик точит когти...
// Мурзик - домашняя кошка
//
// → Птица:
// Кеша летит на высоте...
// Кеша строит гнездо...
//
// 📊 6. СТАТИЧЕСКИЙ ЧЛЕН КЛАССА:
// -------------------------------
// Всего животных создано: 4
//
// 🎭 7. ПОЛИМОРФИЗМ ЧЕРЕЗ МАССИВ БАЗОВОГО ТИПА:
// ---------------------------------------------
// Вызов MakeSound() для всех животных:
// Шарик лает: Гав-гав!
// Мурзик мяукает: Мяяяу!
// Кеша поет: Чик-чирик!
//
// 📝 8. ПЕРЕОПРЕДЕЛЕНИЕ ToString():
// ----------------------------------
// Имя: Шарик, Возраст: 4, Вес: 15,5 кг
// Имя: Мурзик, Возраст: 2, Вес: 4,2 кг
// Имя: Кеша, Возраст: 1, Вес: 0,5 кг
//
// 🛡️ 9. ВАЛИДАЦИЯ В СЕТТЕРАХ:
// ---------------------------
// Попытка установить отрицательный вес:
// ✓ Вес собаки остался: 15,5 кг (отрицательное значение отклонено)
//
// Попытка установить пустое имя:
// ✓ Имя кошки осталось: 'Мурзик' (пустое значение отклонено)
//
// ╔════════════════════════════════════╗
// ║         ИТОГИ ДЕМОСТРАЦИИ          ║
// ╚════════════════════════════════════╝
// ✓ Создано животных всего: 4
// ✓ Продемонстрировано:
//   • Структура класса и наследование
//   • Свойства с геттерами/сеттерами
//   • Статические и обычные члены
//   • Переопределение методов (полиморфизм)
//   • Валидация данных в свойствах
//   • Специфичные методы производных классов
